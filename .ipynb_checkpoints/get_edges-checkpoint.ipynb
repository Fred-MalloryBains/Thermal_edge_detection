# %%
from pathlib import Path 
import numpy as np 
import cv2

from scipy import ndimage
import numpy as np 
from PIL import Image

# %%
data_dir = Path("../thermal/raw_data").expanduser()
all_files = list(data_dir.glob("*")) 
print(len(all_files))
# Out:
# 40

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 all_files = []
# ----> 3 for lwir_dir in thermal_paths:
#       4     if lwir_dir.is_dir():
#       5         files = list(lwir_dir.iterdir())
#
# NameError: name 'thermal_paths' is not defined

# %%
img = cv2.imread(str(all_files[0]), cv2.IMREAD_GRAYSCALE)
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
edges = clahe.apply(img)
edges = cv2.Canny(edges, 70, 130)
Image.fromarray(edges).save("../../outputs/edges.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       3 edges = clahe.apply(img)
#       4 edges = cv2.Canny(edges, 70, 130)
# ----> 5 Image.fromarray(edges).save("../../outputs/edges.png")
#
# NameError: name 'Image' is not defined
